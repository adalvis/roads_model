# %% [markdown]
# # Distributed Road Erosion Model Tutorial

# %% [markdown]
# In this tutorial, we run the full distributed road erosion model (i.e., all three components discussed in the README!) to get an estimate of annual sediment load from the road.

# %% [markdown]
# ### Load necessary `python` packages and set some defaults

# %%
import numpy as np
import time
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from landlab import RasterModelGrid 
from landlab.io import native_landlab
from landlab.components import TruckPassErosion
from landlab.components import FlowAccumulator, FastscapeEroder
from landlab.plot.imshow import imshow_grid
from landlab.plot.drainage_plot import drainage_plot

mpl.rcParams['font.family'] = 'sans-serif'
mpl.rcParams['font.weight'] = 'medium'
mpl.rcParams['axes.labelweight'] = 'normal'

np.set_printoptions(threshold=np.inf)

# %% [markdown]
# ### Creating a synthetic grid
#
# For this tutorial, we're going to create a synthetic grid (i.e., make our own DEM!) with a ditch line. We're going to develop a `python` function so we can easily change node spacing depending on whether we're using a node size of a full-tire width or a half-tire-width. We'll call `ErodibleGrid` before we run our full model.
#
# Within `ErodibleGrid`, we call Landlab's `RasterModelGrid` to create a raster grid, and we add a few fields to the grid (e.g., `'topographic__elevation'`, `'roughness'`) with data.

# %%
def ErodibleGrid(nrows, ncols, spacing, full_tire):
    mg = RasterModelGrid((nrows,ncols),spacing)
    z = mg.add_zeros('topographic__elevation', at='node') #create the topographic__elevation field
    road_flag = mg.add_zeros('flag', at='node') #create a road_flag field for determining whether a 
                                                #node is part of the road or the ditch line
    n = mg.add_zeros('roughness', at='node') #create roughness field
    

    mg.set_fixed_value_boundaries_at_grid_edges(False, False, False, True)     
    mg.set_closed_boundaries_at_grid_edges(False, False, False, False) 
    
    if full_tire == False: #When node spacing is half-tire-width
        road_peak = 40 #peak crowning height occurs at this x-location
        up = 0.0067 #rise of slope from ditchline to crown
        down = 0.0067 #rise of slope from crown to fillslope
        
        for g in range(nrows): #loop through road length
            elev = 0 #initialize elevation placeholder
            flag = False #initialize road_flag placeholder
            roughness = 0.1 #initialize roughness placeholder   

            for h in range(ncols): #loop through road width
                if h == 0 or h == 8:
                    elev = 0
                    flag = False
                    roughness = 0.1
                elif h == 1 or h == 7:
                    elev = -0.333375
                    flag = False
                    roughness = 0.1
                elif h == 2 or h == 6:
                    elev = -0.5715
                    flag = False
                    roughness = 0.1
                elif h == 3 or h == 5:
                    elev = -0.714375
                    flag = False
                    roughness = 0.1
                elif h == 4:
                    elev = -0.762
                    flag = False
                    roughness = 0.1
                elif h <= road_peak and h > 8: #update latitudinal slopes based on location related to road_peak
                    elev += up
                    flag = True
                    roughness = 0.05
                else:
                    elev -= down
                    flag = True
                    roughness = 0.05

                z[g*ncols + h] = elev #update elevation based on x & y locations
                road_flag[g*ncols+h] = flag #update road_flag based on x & y locations
                n[g*ncols + h] = roughness #update roughness values based on x & y locations
    elif full_tire == True: #When node spacing is full-tire-width
        road_peak = 20 #peak crowning height occurs at this x-location
        up = 0.0134 #rise of slope from ditchline to crown
        down = 0.0134 #rise of slope from crown to fillslope
        
        for g in range(nrows): #loop through road length
            elev = 0 #initialize elevation placeholder
            flag = False #initialize road_flag placeholder
            roughness = 0.1 #initialize roughness placeholder

            for h in range(ncols): #loop through road width
                if h == 0 or h == 4:
                    elev = 0
                    flag = False
                    roughness = 0.1
                elif h == 1 or h == 3:
                    elev = -0.5715
                    flag = False
                    roughness = 0.1
                elif h == 2:
                    elev = -0.762
                    flag = False
                    roughness = 0.1
                elif h <= road_peak and h > 4: #update latitudinal slopes based on location related to road_peak
                    elev += up
                    flag = True
                    roughness = 0.05
                else:
                    elev -= down
                    flag = True
                    roughness = 0.05

                z[g*ncols + h] = elev #update elevation based on x & y locations
                road_flag[g*ncols+h] = flag #update road_flag based on x & y locations
                n[g*ncols + h] = roughness #update roughness values based on x & y locations
        
    z += mg.node_y*0.05 #add longitudinal slope to road segment
    road_flag = road_flag.astype(bool) #Make sure road_flag is a boolean array
                
    return(mg, z, road_flag, n)

# %% [markdown]
# ### 1. Create grid using half-tire-width node spacing

# %% [markdown]
# We'll first call `ErodibleGrid` with the values needed to create a synthetic grid that is ~80m long by ~10.5m wide (including the ditch line) using half-tire-width node spacing (~0.15m). We'll also add small perturbations to the road surface such that there is a slightly more interesting topography.

# %%
np.random.seed(7)

mg, z, road_flag, n = ErodibleGrid(540,72,0.1475,False) #half tire width
noise_amplitude=0.007

z[road_flag==1] += noise_amplitude * np.random.rand(
    len(z[road_flag==1])
)

#add depth fields that will update in the component
mg.at_node['active__depth'] = np.ones(540*72)*0.02
mg.at_node['surfacing__depth'] = np.ones(540*72)*0.23
mg.at_node['ballast__depth'] = np.ones(540*72)*2.0

#add absolute elevation fields that will update based on z updates
mg.at_node['active__elev'] = z
mg.at_node['surfacing__elev'] = z - mg.at_node['active__depth']
mg.at_node['ballast__elev'] = z - mg.at_node['active__depth']\
     - mg.at_node['surfacing__depth']

# %%
# Plot the initial surface
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 6))
imshow_grid(mg, z, plot_name='Synthetic road', var_name='Elevation', var_units='m',\
    grid_units=('m', 'm'), cmap='terrain', color_for_closed='black', vmin=0, vmax=4)
plt.xlabel('Road width (m)')
plt.ylabel('Road length (m)')
plt.tight_layout()
plt.show()

# %%
# Prepare some variables for later
xsec_pre = mg.at_node['topographic__elevation'][4392*2:4428*2].copy() #half tire width

X = mg.node_x.reshape(mg.shape)
Y = mg.node_y.reshape(mg.shape)
Z = z.reshape(mg.shape).copy()

# %% [markdown]
# ### 2. Instantiate the components

# %% [markdown]
# Next, we need to instantiate all three components that we'll be running:
# 1. `TruckPassErosion` - Remember that we're using the half-tire-width node spacing! And our main variables controlling how the layers interact are the scattering loss, the pumping constants, and the crushing constants.
# 2. `FlowAccumulator` - This time, we're defining the flow director to be 'D8' to be compatible with `FastscapeEroder`.
# 3. `FastscapeEroder` - The main information needed here is the erodibility of each node or $K_{sp}$; this is a guess. We also pass a discharge field to ensure the correct calculations.

# %%
center = 40
half_width = 7 
full_tire = False
K_sp=np.ones((540*72))*0.45 #erodibility in SP eqtn; can be array; this is a guess
K_sp[road_flag==0] = 0.05 #erodibility of the ditch line

tpe = TruckPassErosion(mg, 
                       center, 
                       half_width, 
                       full_tire, 
                       truck_num=5,
                       scat_loss=8e-5,
                       u_ps=5e-07,
                       u_pb=1e-07,
                       k_cs=1e-07,
                       k_cb=1e-07,
                       )
fa = FlowAccumulator(mg,
                     surface='topographic__elevation',
                     runoff_rate=1.38889e-6, #5 mm/hr converted to m/s
                     flow_director='D8',
                     )
sp = FastscapeEroder(mg, 
                     K_sp=K_sp,
                     threshold_sp=0.0,
                     discharge_field='surface_water__discharge',
                     erode_flooded_nodes=True
                     )

# %% [markdown]
# ### 3. Define some parameters

# %% [markdown]
# We need to define or instantiate a number of parameters and variables needed for the full model run.

# %%
# Create some empty lists
intensity_arr=[]
dt_arr = []
dz_arr_cum = []
sa_arr=[]
ss_arr=[]
sb_arr=[]
tracks=[]

# Define a few limits and initial conditions
z_limit = mg.at_node['topographic__elevation'] - mg.at_node['active__depth']
z_ini_cum = mg.at_node['topographic__elevation'].copy()
mask = road_flag

# Define how long to run the model
model_end = int(365) #days

# %% [markdown]
# ### 4. Run the full model

# %% [markdown]
# Now, we can run the model. Because there are a number of random elements, we use `np.random.seed` to give us the same random numbers for each model run. A few things happen as we loop through the model:
# * Run `tpe.run_one_step()` to develop ruts.
# * Define the probability that a storm is occurring on that day.
#     * If the random number generator yields a value larger than the probability, no rainfall occurs.
#     * If the random number generators yields a value less than or equal to the probability, rainfall occurs and it is based on an exponential distribution centered around 5 mm/hr.
#         * When rainfall occurs, update the runoff rate fed to `FlowAccumulator`, run `fa.accumulate_flow()` to route flow, and run `sp.run_one_step()` to erode the surface.
#         * We can look at maps of the surface water discharge and elevation change on each day it rains. (If you would like to look at these figures, please uncomment the commented lines of code!!)
# * Save the updated depths of each road layer.
#
# Note that the number of truck passes is printed out for every day, and the rainfall intensity and duration are printed out whenever there is rainfall.

# %%
np.random.seed(7)

for i in range(0, model_end): #loop through model days
    tpe.run_one_step()
    tracks.append(tpe.tire_tracks)
    print('Number of truck passes: ',tpe._truck_num)

    p_storm = 0.25
    chance = np.random.uniform()

    if chance > p_storm:
        intensity_arr.append(0)
        dt_arr.append(0)

        dz_cum = z-z_ini_cum
        dz_arr_cum.append(z.mean()-z_ini_cum.mean())

    elif chance <= p_storm:
        dt = np.random.exponential(scale=1/6)
        print('Duration of rainfall [days]: ',dt)
        dt_arr.append(dt)

        intensity = np.random.exponential(scale=5)
        print('Intensity of rainfall [mm/hr]: ', intensity)
        intensity_arr.append(intensity)

        mg.at_node['water__unit_flux_in'] = np.ones(540*72)*intensity*2.77778e-7
        fa.accumulate_flow()
        sp.run_one_step(dt)
        if any(z[tracks[i][0]] <= z_limit[tracks[i][0]]) or\
            any(z[tracks[i][1]] <= z_limit[tracks[i][1]]):
            z[tracks[i][0:2]] = z_limit[tracks[i][0:2]]
        
        # fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 6))
        # im = imshow_grid(mg,'surface_water__discharge', var_name='Q', 
        #              plot_name='Steady state Q, t = %i days' %i,
        #              var_units='$m^3/s$', grid_units=('m','m'), 
        #              cmap='Blues', vmin=0, vmax=5e-6, shrink=0.9)
        # plt.xlabel('Road width (m)')
        # plt.ylabel('Road length (m)')
        # plt.tight_layout()
        # # plt.savefig('output/Q_%i_days.png' %i)
        # plt.show()

        dz_cum = z-z_ini_cum
        dz_arr_cum.append((z.mean()-z_ini_cum.mean()))

        mg.add_field('dz_cum', dz_cum, at='node', units='m', clobber=True)

        # fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 6))
        # plt.xlabel('Road width (m)')
        # plt.ylabel('Road length (m)')
        # im = imshow_grid(mg,'dz_cum', var_name='Cumulative dz', var_units='m', 
        #             plot_name='Elevation change, t = %i days' %i,
        #             grid_units=('m','m'), cmap='RdBu', vmin=-0.002, 
        #             vmax=0.002, shrink=0.9)
        # plt.xlabel('Road width (m)')
        # plt.ylabel('Road length (m)')
        # plt.tight_layout()
        # # plt.savefig('output/dz_cum_%i_days.png' %i)
        # plt.show()


    sa = mg.at_node['topographic__elevation'].mean()\
            - mg.at_node['surfacing__elev'].mean()
    sa_arr.append(sa)
    ss = mg.at_node['surfacing__depth'].mean()
    ss_arr.append(ss)
    sb = mg.at_node['ballast__depth'].mean()
    sb_arr.append(sb)
# Out:
# Number of truck passes:  6
# Duration of rainfall [days]:  0.052095774084211774
# Intensity of rainfall [mm/hr]:  3.464561049094261
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  4
# Duration of rainfall [days]:  0.20596470599410688
# Intensity of rainfall [mm/hr]:  3.7153186603619903
# Number of truck passes:  5
# Duration of rainfall [days]:  0.5585964959829028
# Intensity of rainfall [mm/hr]:  14.506496372964659
# Number of truck passes:  5
# Number of truck passes:  4
# Duration of rainfall [days]:  0.08932925595240261
# Intensity of rainfall [mm/hr]:  2.972129195150666
# Number of truck passes:  9
# Number of truck passes:  6
# Number of truck passes:  6
# Number of truck passes:  5
# Duration of rainfall [days]:  0.04365403967110202
# Intensity of rainfall [mm/hr]:  5.381687085769844
# Number of truck passes:  3
# Number of truck passes:  5
# Duration of rainfall [days]:  0.3488570688154145
# Intensity of rainfall [mm/hr]:  11.994514408175164
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  2
# Number of truck passes:  2
# Number of truck passes:  7
# Duration of rainfall [days]:  0.29595509616908605
# Intensity of rainfall [mm/hr]:  13.060038113976011
# Number of truck passes:  5
# Number of truck passes:  3
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  7
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  7
# Duration of rainfall [days]:  0.5758360009503639
# Intensity of rainfall [mm/hr]:  2.59821895076554
# Number of truck passes:  4
# Duration of rainfall [days]:  0.5423900252449674
# Intensity of rainfall [mm/hr]:  3.7772983573544967
# Number of truck passes:  4
# Duration of rainfall [days]:  0.018685957566524438
# Intensity of rainfall [mm/hr]:  0.8080376111960469
# Number of truck passes:  2
# Number of truck passes:  2
# Duration of rainfall [days]:  0.23999988144295162
# Intensity of rainfall [mm/hr]:  13.913988971908566
# Number of truck passes:  1
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  6
# Duration of rainfall [days]:  0.03970745330460105
# Intensity of rainfall [mm/hr]:  13.680295545348065
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.22073531751310332
# Intensity of rainfall [mm/hr]:  8.249033177112018
# Number of truck passes:  4
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  10
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  8
# Number of truck passes:  8
# Number of truck passes:  7
# Number of truck passes:  6
# Duration of rainfall [days]:  0.08871722752191216
# Intensity of rainfall [mm/hr]:  5.1940940842304535
# Number of truck passes:  4
# Number of truck passes:  9
# Number of truck passes:  3
# Duration of rainfall [days]:  0.2672117543628194
# Intensity of rainfall [mm/hr]:  5.795275662673994
# Number of truck passes:  3
# Duration of rainfall [days]:  0.017785943061535595
# Intensity of rainfall [mm/hr]:  16.112498368055864
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  7
# Number of truck passes:  1
# Number of truck passes:  8
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  3
# Duration of rainfall [days]:  0.019377472352203
# Intensity of rainfall [mm/hr]:  1.740668888975865
# Number of truck passes:  4
# Duration of rainfall [days]:  0.004741716973045098
# Intensity of rainfall [mm/hr]:  2.8199746246176325
# Number of truck passes:  3
# Number of truck passes:  3
# Number of truck passes:  5
# Number of truck passes:  7
# Duration of rainfall [days]:  0.3417842924621242
# Intensity of rainfall [mm/hr]:  6.006452938620523
# Number of truck passes:  7
# Duration of rainfall [days]:  0.011639229522940494
# Intensity of rainfall [mm/hr]:  2.858824428493352
# Number of truck passes:  5
# Duration of rainfall [days]:  0.11775776967441111
# Intensity of rainfall [mm/hr]:  2.1944315060668127
# Number of truck passes:  5
# Number of truck passes:  0
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  7
# Number of truck passes:  3
# Duration of rainfall [days]:  0.44927013752563527
# Intensity of rainfall [mm/hr]:  8.205826689477108
# Number of truck passes:  5
# Number of truck passes:  0
# Number of truck passes:  3
# Number of truck passes:  5
# Duration of rainfall [days]:  0.14124351221687462
# Intensity of rainfall [mm/hr]:  1.036763245624377
# Number of truck passes:  5
# Number of truck passes:  5
# Duration of rainfall [days]:  0.1658770102962569
# Intensity of rainfall [mm/hr]:  2.5561787310394517
# Number of truck passes:  6
# Number of truck passes:  8
# Number of truck passes:  5
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  4
# Duration of rainfall [days]:  0.06615777925336092
# Intensity of rainfall [mm/hr]:  3.998198091120786
# Number of truck passes:  6
# Number of truck passes:  10
# Duration of rainfall [days]:  0.24097130940071143
# Intensity of rainfall [mm/hr]:  5.061707321234352
# Number of truck passes:  2
# Number of truck passes:  3
# Number of truck passes:  9
# Number of truck passes:  6
# Number of truck passes:  9
# Number of truck passes:  3
# Duration of rainfall [days]:  0.160587096850276
# Intensity of rainfall [mm/hr]:  13.534845830690305
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  3
# Number of truck passes:  3
# Number of truck passes:  8
# Number of truck passes:  5
# Number of truck passes:  9
# Number of truck passes:  3
# Duration of rainfall [days]:  0.045250498883502965
# Intensity of rainfall [mm/hr]:  8.184088901954404
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.06202695555705334
# Intensity of rainfall [mm/hr]:  4.922947431102942
# Number of truck passes:  7
# Number of truck passes:  3
# Duration of rainfall [days]:  0.100036661669974
# Intensity of rainfall [mm/hr]:  1.34305425868504
# Number of truck passes:  5
# Number of truck passes:  7
# Duration of rainfall [days]:  0.05608396862108923
# Intensity of rainfall [mm/hr]:  4.491467765270338
# Number of truck passes:  7
# Number of truck passes:  4
# Number of truck passes:  5
# Duration of rainfall [days]:  0.24465448858394626
# Intensity of rainfall [mm/hr]:  1.1296597422889518
# Number of truck passes:  3
# Duration of rainfall [days]:  0.14479438656628857
# Intensity of rainfall [mm/hr]:  12.605598549561705
# Number of truck passes:  5
# Number of truck passes:  7
# Number of truck passes:  6
# Number of truck passes:  7
# Duration of rainfall [days]:  0.011075729796429951
# Intensity of rainfall [mm/hr]:  0.2633203604890665
# Number of truck passes:  7
# Number of truck passes:  1
# Number of truck passes:  4
# Number of truck passes:  3
# Duration of rainfall [days]:  0.014584195888354768
# Intensity of rainfall [mm/hr]:  3.7343530082187746
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  4
# Number of truck passes:  2
# Number of truck passes:  3
# Number of truck passes:  5
# Duration of rainfall [days]:  0.0265233019558569
# Intensity of rainfall [mm/hr]:  20.47922892802315
# Number of truck passes:  6
# Duration of rainfall [days]:  0.1669559733530715
# Intensity of rainfall [mm/hr]:  2.3171767221496085
# Number of truck passes:  4
# Duration of rainfall [days]:  0.30490611154973024
# Intensity of rainfall [mm/hr]:  1.1640317826134146
# Number of truck passes:  8
# Number of truck passes:  5
# Number of truck passes:  8
# Number of truck passes:  5
# Duration of rainfall [days]:  0.11111890956274584
# Intensity of rainfall [mm/hr]:  4.421430793248194
# Number of truck passes:  0
# Duration of rainfall [days]:  0.015024768098745749
# Intensity of rainfall [mm/hr]:  1.43709274602153
# Number of truck passes:  2
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  5
# Duration of rainfall [days]:  0.16192056889865086
# Intensity of rainfall [mm/hr]:  5.582395906391628
# Number of truck passes:  5
# Number of truck passes:  3
# Duration of rainfall [days]:  0.18195497515257322
# Intensity of rainfall [mm/hr]:  4.187224729985556
# Number of truck passes:  5
# Number of truck passes:  8
# Number of truck passes:  3
# Number of truck passes:  1
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  3
# Number of truck passes:  9
# Number of truck passes:  6
# Number of truck passes:  5
# Duration of rainfall [days]:  0.01051212801872806
# Intensity of rainfall [mm/hr]:  6.019959142716718
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  3
# Duration of rainfall [days]:  0.2931413952280556
# Intensity of rainfall [mm/hr]:  1.1403048063250587
# Number of truck passes:  5
# Duration of rainfall [days]:  0.312085109164591
# Intensity of rainfall [mm/hr]:  0.5768662712614563
# Number of truck passes:  5
# Number of truck passes:  2
# Duration of rainfall [days]:  1.0107009465615757
# Intensity of rainfall [mm/hr]:  2.8369644633876874
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  8
# Number of truck passes:  7
# Number of truck passes:  2
# Duration of rainfall [days]:  0.03952666841600898
# Intensity of rainfall [mm/hr]:  2.562034800103414
# Number of truck passes:  1
# Number of truck passes:  2
# Duration of rainfall [days]:  0.10877448007916657
# Intensity of rainfall [mm/hr]:  2.091391638414147
# Number of truck passes:  6
# Number of truck passes:  1
# Duration of rainfall [days]:  0.20469746548690154
# Intensity of rainfall [mm/hr]:  1.3240620465698894
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  2
# Number of truck passes:  9
# Duration of rainfall [days]:  0.01641905956174156
# Intensity of rainfall [mm/hr]:  4.77232039674452
# Number of truck passes:  4
# Duration of rainfall [days]:  0.3258898179703055
# Intensity of rainfall [mm/hr]:  0.417271934230004
# Number of truck passes:  5
# Number of truck passes:  9
# Number of truck passes:  1
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  1
# Number of truck passes:  8
# Duration of rainfall [days]:  0.4257064369513004
# Intensity of rainfall [mm/hr]:  0.5116989656510238
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  6
# Duration of rainfall [days]:  0.0011880584167584375
# Intensity of rainfall [mm/hr]:  1.8274942285092193
# Number of truck passes:  5
# Number of truck passes:  3
# Number of truck passes:  5
# Number of truck passes:  9
# Duration of rainfall [days]:  0.12812458718573944
# Intensity of rainfall [mm/hr]:  1.4121462542433543
# Number of truck passes:  5
# Duration of rainfall [days]:  0.14074175523772947
# Intensity of rainfall [mm/hr]:  0.6667657092376088
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  5
# Duration of rainfall [days]:  0.10192174267521614
# Intensity of rainfall [mm/hr]:  0.2473229873110102
# Number of truck passes:  6
# Duration of rainfall [days]:  0.26901598609253907
# Intensity of rainfall [mm/hr]:  5.997001315179514
# Number of truck passes:  8
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  4
# Duration of rainfall [days]:  0.07474092590687612
# Intensity of rainfall [mm/hr]:  0.09039758514227791
# Number of truck passes:  8
# Number of truck passes:  2
# Duration of rainfall [days]:  0.01654596605261094
# Intensity of rainfall [mm/hr]:  12.079741390647033
# Number of truck passes:  7
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  6
# Number of truck passes:  8
# Duration of rainfall [days]:  0.06902808581990016
# Intensity of rainfall [mm/hr]:  4.387652721562853
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  7
# Number of truck passes:  0
# Number of truck passes:  5
# Number of truck passes:  3
# Duration of rainfall [days]:  0.17070088282093043
# Intensity of rainfall [mm/hr]:  0.6816246762744496
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  5
# Duration of rainfall [days]:  0.18478138963894847
# Intensity of rainfall [mm/hr]:  2.0957365993527204
# Number of truck passes:  5
# Number of truck passes:  1
# Number of truck passes:  2
# Duration of rainfall [days]:  0.09916335274652704
# Intensity of rainfall [mm/hr]:  0.9055686325713925
# Number of truck passes:  3
# Duration of rainfall [days]:  0.4724712833661056
# Intensity of rainfall [mm/hr]:  2.1439879290710566
# Number of truck passes:  8
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  1
# Number of truck passes:  7
# Number of truck passes:  6
# Duration of rainfall [days]:  0.49644878244361745
# Intensity of rainfall [mm/hr]:  6.5941947781332155
# Number of truck passes:  6
# Number of truck passes:  10
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.05617638367533054
# Intensity of rainfall [mm/hr]:  13.149425634677039
# Number of truck passes:  4
# Number of truck passes:  3
# Duration of rainfall [days]:  0.4120220859672139
# Intensity of rainfall [mm/hr]:  2.7328484443731416
# Number of truck passes:  11
# Duration of rainfall [days]:  0.054605129809217154
# Intensity of rainfall [mm/hr]:  3.2707745515473703
# Number of truck passes:  7
# Number of truck passes:  8
# Duration of rainfall [days]:  0.18058545004036045
# Intensity of rainfall [mm/hr]:  3.6141998648350038
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  3
# Number of truck passes:  3
# Duration of rainfall [days]:  0.1239413560042041
# Intensity of rainfall [mm/hr]:  1.851136899968836
# Number of truck passes:  2
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.009496412013758572
# Intensity of rainfall [mm/hr]:  1.9599302365775004
# Number of truck passes:  2
# Number of truck passes:  5
# Number of truck passes:  5
# Duration of rainfall [days]:  0.5218253840191509
# Intensity of rainfall [mm/hr]:  4.389559194985061
# Number of truck passes:  3
# Number of truck passes:  7
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  1
# Duration of rainfall [days]:  0.2023859652760234
# Intensity of rainfall [mm/hr]:  7.564255871207668
# Number of truck passes:  3
# Number of truck passes:  6
# Duration of rainfall [days]:  0.6299004512313635
# Intensity of rainfall [mm/hr]:  8.21385992545017
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  3
# Duration of rainfall [days]:  0.4083270808623528
# Intensity of rainfall [mm/hr]:  2.6074675331607464
# Number of truck passes:  6
# Number of truck passes:  3
# Number of truck passes:  9
# Number of truck passes:  2
# Duration of rainfall [days]:  0.047799617507329806
# Intensity of rainfall [mm/hr]:  6.875989659214388
# Number of truck passes:  5
# Number of truck passes:  5
# Duration of rainfall [days]:  0.16468576175636834
# Intensity of rainfall [mm/hr]:  4.698251121664101
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  10
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  4
# Duration of rainfall [days]:  0.008681976888578127
# Intensity of rainfall [mm/hr]:  2.0733484927602457
# Number of truck passes:  8
# Number of truck passes:  1
# Duration of rainfall [days]:  0.2166417354273217
# Intensity of rainfall [mm/hr]:  0.5660427602952816
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  9
# Number of truck passes:  2
# Duration of rainfall [days]:  0.0056121271355237265
# Intensity of rainfall [mm/hr]:  3.6644312872040152
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  3
# Duration of rainfall [days]:  0.08118235640901647
# Intensity of rainfall [mm/hr]:  0.45960817802622667
# Number of truck passes:  4
# Number of truck passes:  2
# Duration of rainfall [days]:  0.007846904628105743
# Intensity of rainfall [mm/hr]:  0.6913173153363474
# Number of truck passes:  7
# Duration of rainfall [days]:  0.02021857742845546
# Intensity of rainfall [mm/hr]:  0.4246420658466552
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  5
# Duration of rainfall [days]:  0.3311575405295488
# Intensity of rainfall [mm/hr]:  0.9276771321188965
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.48655629789934385
# Intensity of rainfall [mm/hr]:  2.706057461792055
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  1
# Number of truck passes:  5
# Duration of rainfall [days]:  0.10427885627675154
# Intensity of rainfall [mm/hr]:  1.171706459852965
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  6
# Duration of rainfall [days]:  0.08798255299494673
# Intensity of rainfall [mm/hr]:  2.503493588984588
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  8
# Number of truck passes:  6
# Duration of rainfall [days]:  0.19489973142255435
# Intensity of rainfall [mm/hr]:  4.251606390173917
# Number of truck passes:  1
# Duration of rainfall [days]:  0.16254500587893111
# Intensity of rainfall [mm/hr]:  2.2502150695314898
# Number of truck passes:  4
# Number of truck passes:  0
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  6
# Duration of rainfall [days]:  0.004770231038818195
# Intensity of rainfall [mm/hr]:  3.42428890331004
# Number of truck passes:  3
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  5
# Duration of rainfall [days]:  0.04143570456980539
# Intensity of rainfall [mm/hr]:  10.860253553365098
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  6
# Duration of rainfall [days]:  0.02201581062279532
# Intensity of rainfall [mm/hr]:  16.471493757448002
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  7
# Duration of rainfall [days]:  0.06655077439037285
# Intensity of rainfall [mm/hr]:  4.21169399369088
# Number of truck passes:  12
# Duration of rainfall [days]:  0.009084817059542243
# Intensity of rainfall [mm/hr]:  1.223386009710323
# Number of truck passes:  6
# Number of truck passes:  4
# Duration of rainfall [days]:  0.16429448597059204
# Intensity of rainfall [mm/hr]:  3.4098464327700304
# Number of truck passes:  3
# Number of truck passes:  7
# Duration of rainfall [days]:  0.16504990585122598
# Intensity of rainfall [mm/hr]:  3.129536864160332
# Number of truck passes:  6
# Number of truck passes:  6
# Duration of rainfall [days]:  0.03677570378452031
# Intensity of rainfall [mm/hr]:  6.332383816853798
# Number of truck passes:  9

# %% [markdown]
# ### 5. Examine the results

# %% [markdown]
# #### Stochastically generated rainfall

# %%
plt.bar(range(0,model_end), np.multiply(intensity_arr,np.multiply(dt_arr,24)))
plt.xlabel('Day')
plt.ylabel('Rainfall [mm]')
plt.xlim(0,model_end)
plt.show()
print('Total annual rainfall: ', sum(np.multiply(intensity_arr,np.multiply(dt_arr,24))))

plt.plot(range(0,model_end), intensity_arr)
plt.xlabel('Day')
plt.ylabel('Rainfall intensity [mm/hr]')
plt.xlim(0,model_end)
plt.show()
# Out:
# Total annual rainfall:  1868.1854770563752

# %% [markdown]
# #### Cross section

# %%
xsec_active = mg.at_node['active__elev'][4392*2:4428*2]
xsec_surf =  mg.at_node['surfacing__elev'][4392*2:4428*2] 
xsec_ball = mg.at_node['ballast__elev'][4392*2:4428*2]

plt.figure(figsize=(8,3), layout='tight')
plt.plot(X[36], xsec_pre, color='gray', linestyle='-.', label='Before')
plt.plot(X[36], xsec_active, color ='black', linestyle='-', label = 'After - Active elevation')
plt.plot(X[36], xsec_surf, color ='magenta', linestyle='-', label = 'After - Surfacing elevation')
plt.plot(X[36], xsec_ball, color ='cyan', linestyle='-', label = 'After - Ballast elevation ')
plt.xlim(0,10)
plt.xlabel('Road width (m)')
plt.ylabel('Elevation (m)')
plt.legend()
plt.show()

# %% [markdown]
# #### 3D rendition of the road surface

# %%
X = mg.node_x.reshape(mg.shape)
Y = mg.node_y.reshape(mg.shape)
Z = z.reshape(mg.shape)

fig = plt.figure(figsize = (14,7))
ax = fig.add_subplot(111, projection='3d')
ax.get_proj = lambda: np.dot(Axes3D.get_proj(ax), np.diag([1, 2, 1, 1]))
ax.plot_surface(X, Y, Z, color='gray')
ax.view_init(elev=12, azim=-105)
ax.dist = 17
ax.set_xlim(0, 10)
ax.set_ylim(0, 80)
ax.set_zlim(0, 4)
ax.set_zticks(np.arange(0, 5, 1))
ax.set_xlabel('Road width (m)', labelpad=10)
ax.set_ylabel('Road length (m)', labelpad=17)
ax.set_zlabel('Elevation (m)', labelpad=10)
ax.set_zticklabels(labels=('0','1','2','3','4'))
plt.show()

# %% [markdown]
# #### Map

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 6))
imshow_grid(mg, z, plot_name='Synthetic road with ruts', var_name='Elevation', var_units='m',\
    grid_units=('m', 'm'), cmap='terrain', color_for_closed='black', vmin=0, vmax=4)
plt.xlabel('Road width (m)')
plt.ylabel('Road length (m)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Individual layer elevation changes
#
# Note that the surfacing and the ballast are changing by *very* small amounts!

# %%
plt.plot(range(0,model_end), sa_arr)
plt.xlabel('Day')
plt.ylabel('Average active layer depth [m]')
plt.xlim(0,model_end)
plt.show()

plt.plot(range(0,model_end), ss_arr)
plt.xlabel('Day')
plt.ylabel('Average surfacing layer depth [m]')
plt.xlim(0,model_end)
plt.show()

plt.plot(range(0,model_end), sb_arr)
plt.xlabel('Day')
plt.ylabel('Average ballast layer depth [m]')
plt.xlim(0,model_end)
plt.show()

# %% [markdown]
# #### Cumulative elevation change and sediment load per meter of road
#
# And here is the main goal of the model: determining the cumulative elevation change and therefore the sediment load per meter of road! This can be compared to data collected in the field.

# %%
plt.plot(range(0,model_end), np.multiply(dz_arr_cum,1000))
plt.plot(range(0,model_end), np.zeros(len(range(0,model_end))), '--', color='gray')
plt.xlabel('Day')
plt.ylabel('Cumulative mean elevation change [mm]')
plt.xlim(0,model_end)
plt.show()

total_dz = np.abs(min(dz_arr_cum))
print(total_dz)
total_dV = total_dz*0.1475*0.1475*540*72
print(total_dV)
total_load = total_dV*2650
print(total_load)
sed_load = total_load/2

print('Total sediment load: ', sed_load)
# Out:
# 0.0003087097784915116
# 0.2611323535597353
# 692.0007369332985
# Total sediment load:  346.00036846664926

# %% [markdown]
# ## Start again!

# %% [markdown]
# ### 1. Create grid using full-tire-width node spacing

# %%
np.random.seed(7)

mg, z, road_flag, n = ErodibleGrid(270,36,0.295,True)
noise_amplitude=0.007

z[road_flag==1] += noise_amplitude * np.random.rand(
    len(z[road_flag==1])
)

mg.at_node['active__depth'] = np.ones(270*36)*0.02
mg.at_node['surfacing__depth'] = np.ones(270*36)*0.23
mg.at_node['ballast__depth'] = np.ones(270*36)*2.0

#add absolute elevation fields that will update based on z updates
mg.at_node['active__elev'] = z
mg.at_node['surfacing__elev'] = z - mg.at_node['active__depth']
mg.at_node['ballast__elev'] = z - mg.at_node['active__depth']\
     - mg.at_node['surfacing__depth']

# %%
# Plot the initial grid
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 6))
imshow_grid(mg, z, plot_name='Synthetic road', var_name='Elevation', var_units='m',\
    grid_units=('m', 'm'), cmap='terrain', color_for_closed='black', vmin=0, vmax=4)
plt.xlabel('Road width (m)')
plt.ylabel('Road length (m)')
plt.tight_layout()
plt.show()

# %%
# Prep some variables for later
xsec_pre = mg.at_node['topographic__elevation'][2196:2232].copy() #full tire width
mg_pre = mg.at_node['topographic__elevation'].copy()
active_pre = mg.at_node['active__depth'].copy()

X = mg.node_x.reshape(mg.shape)
Y = mg.node_y.reshape(mg.shape)
Z = z.reshape(mg.shape)

# %% [markdown]
# ### 2. Instantiate the components

# %%
center = 20
half_width = 4
full_tire=True
K_sp=np.ones((270*36))*0.45**1.5#erodibility in SP eqtn; can be an array; this is a guess
K_sp[road_flag==0] = 0.05**1.5 #erodibility of the ditch line

tpe = TruckPassErosion(mg, 
                       center, 
                       half_width, 
                       full_tire, 
                       truck_num=5,
                       scat_loss=8e-5,
                       u_ps=5e-07,
                       u_pb=1e-07,
                       k_cs=1e-07,
                       k_cb=1e-07,
                       )
fa = FlowAccumulator(mg,
                     surface='topographic__elevation',
                     runoff_rate=1.38889e-6, #5 mm/hr converted to m/s
                     flow_director='D8',
                     )
sp = FastscapeEroder(mg, 
                     K_sp=K_sp,
                     threshold_sp=0.0,
                     discharge_field='surface_water__discharge',
                     erode_flooded_nodes=True
                     )

# %% [markdown]
# ### 3. Define some parameters

# %%
mask = road_flag
z_limit = mg.at_node['topographic__elevation'] - mg.at_node['active__depth']
bottom_elev = mg.at_node['ballast__elev'].copy() - 2
intensity_arr=[]
dt_arr = []
dz_arr_cum = []
sa_arr=[]
ss_arr=[]
sb_arr=[]
tracks=[]

active_depth_init = mg.at_node['active__depth']
surfacing_depth_init = mg.at_node['surfacing__depth']
ballast_depth_init = mg.at_node['ballast__depth']
z_ini_cum = mg.at_node['topographic__elevation'].copy()

#define how long to run the model
model_end = int(365) #days

# %% [markdown]
# ### 4. Run the full model

# %%
np.random.seed(7)
for i in range(0, model_end): #loop through model days
    z_ini = mg.at_node['topographic__elevation'].copy()
    tpe.run_one_step()
    tracks.append(tpe.tire_tracks)
    print('Number of truck passes: ',tpe._truck_num)
    
    p_storm = 0.25
    
    chance = np.random.uniform()

    if chance > p_storm:
        intensity_arr.append(0)
        dt_arr.append(0)

        dz_cum = z-z_ini_cum
        dz_arr_cum.append(z.mean()-z_ini_cum.mean())

    elif chance <= p_storm:
        dt = np.random.exponential(scale=1/6)
        print('Duration of rainfall [days]: ',dt)
        dt_arr.append(dt)

        intensity = np.random.exponential(scale=5)
        print('Intensity of rainfall [mm/hr]: ', intensity)
        intensity_arr.append(intensity)

        mg.at_node['water__unit_flux_in'] = np.ones(270*36)*intensity*2.77778e-7
        fa.accumulate_flow()
        sp.run_one_step(dt)
        if any(z[tracks[i][0]] <= z_limit[tracks[i][0]]) or\
            any(z[tracks[i][1]] <= z_limit[tracks[i][1]]):
            z[tracks[i][0:2]] = z_limit[tracks[i][0:2]]
        
        # fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 6))
        # im = imshow_grid(mg,'surface_water__discharge', var_name='Q', 
        #              plot_name='Steady state Q, t = %i days' %i,
        #              var_units='$m^3/s$', grid_units=('m','m'), 
        #              cmap='Blues', vmin=0, vmax=5e-6, shrink=0.9)
        # plt.xlabel('Road width (m)')
        # plt.ylabel('Road length (m)')
        # plt.tight_layout()
        # # plt.savefig('output/Q_%i_days.png' %i)
        # plt.show()

        dz_cum = z-z_ini_cum
        dz_arr_cum.append(z.mean()-z_ini_cum.mean())
        
        # mg.add_field('dz_cum', dz_cum, at='node', units='m', clobber=True)
        # fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 6))
        # plt.xlabel('Road width (m)')
        # plt.ylabel('Road length (m)')
        # im = imshow_grid(mg,'dz_cum', var_name='Cumulative dz', var_units='m', 
        #              plot_name='Elevation change, t = %i days' %i,
        #              grid_units=('m','m'), cmap='RdBu', vmin=-0.001, 
        #              vmax=0.001, shrink=0.9)
        # plt.xlabel('Road width (m)')
        # plt.ylabel('Road length (m)')
        # plt.tight_layout()
        # # plt.savefig('output/dz_cum_%i_days.png' %i)
        # plt.show()

    sa = mg.at_node['topographic__elevation'].mean()\
            - mg.at_node['surfacing__elev'].mean()
    sa_arr.append(sa)
    ss = mg.at_node['surfacing__depth'].mean()
    ss_arr.append(ss)
    sb = mg.at_node['ballast__depth'].mean()
    sb_arr.append(sb)
# Out:
# Number of truck passes:  6
# Duration of rainfall [days]:  0.052095774084211774
# Intensity of rainfall [mm/hr]:  3.464561049094261
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  4
# Duration of rainfall [days]:  0.20596470599410688
# Intensity of rainfall [mm/hr]:  3.7153186603619903
# Number of truck passes:  5
# Duration of rainfall [days]:  0.5585964959829028
# Intensity of rainfall [mm/hr]:  14.506496372964659
# Number of truck passes:  5
# Number of truck passes:  4
# Duration of rainfall [days]:  0.08932925595240261
# Intensity of rainfall [mm/hr]:  2.972129195150666
# Number of truck passes:  9
# Number of truck passes:  6
# Number of truck passes:  6
# Number of truck passes:  5
# Duration of rainfall [days]:  0.04365403967110202
# Intensity of rainfall [mm/hr]:  5.381687085769844
# Number of truck passes:  3
# Number of truck passes:  5
# Duration of rainfall [days]:  0.3488570688154145
# Intensity of rainfall [mm/hr]:  11.994514408175164
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  2
# Number of truck passes:  2
# Number of truck passes:  7
# Duration of rainfall [days]:  0.29595509616908605
# Intensity of rainfall [mm/hr]:  13.060038113976011
# Number of truck passes:  5
# Number of truck passes:  3
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  7
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  7
# Duration of rainfall [days]:  0.5758360009503639
# Intensity of rainfall [mm/hr]:  2.59821895076554
# Number of truck passes:  4
# Duration of rainfall [days]:  0.5423900252449674
# Intensity of rainfall [mm/hr]:  3.7772983573544967
# Number of truck passes:  4
# Duration of rainfall [days]:  0.018685957566524438
# Intensity of rainfall [mm/hr]:  0.8080376111960469
# Number of truck passes:  2
# Number of truck passes:  2
# Duration of rainfall [days]:  0.23999988144295162
# Intensity of rainfall [mm/hr]:  13.913988971908566
# Number of truck passes:  1
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  6
# Duration of rainfall [days]:  0.03970745330460105
# Intensity of rainfall [mm/hr]:  13.680295545348065
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.22073531751310332
# Intensity of rainfall [mm/hr]:  8.249033177112018
# Number of truck passes:  4
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  10
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  8
# Number of truck passes:  8
# Number of truck passes:  7
# Number of truck passes:  6
# Duration of rainfall [days]:  0.08871722752191216
# Intensity of rainfall [mm/hr]:  5.1940940842304535
# Number of truck passes:  4
# Number of truck passes:  9
# Number of truck passes:  3
# Duration of rainfall [days]:  0.2672117543628194
# Intensity of rainfall [mm/hr]:  5.795275662673994
# Number of truck passes:  3
# Duration of rainfall [days]:  0.017785943061535595
# Intensity of rainfall [mm/hr]:  16.112498368055864
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  7
# Number of truck passes:  1
# Number of truck passes:  8
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  3
# Duration of rainfall [days]:  0.019377472352203
# Intensity of rainfall [mm/hr]:  1.740668888975865
# Number of truck passes:  4
# Duration of rainfall [days]:  0.004741716973045098
# Intensity of rainfall [mm/hr]:  2.8199746246176325
# Number of truck passes:  3
# Number of truck passes:  3
# Number of truck passes:  5
# Number of truck passes:  7
# Duration of rainfall [days]:  0.3417842924621242
# Intensity of rainfall [mm/hr]:  6.006452938620523
# Number of truck passes:  7
# Duration of rainfall [days]:  0.011639229522940494
# Intensity of rainfall [mm/hr]:  2.858824428493352
# Number of truck passes:  5
# Duration of rainfall [days]:  0.11775776967441111
# Intensity of rainfall [mm/hr]:  2.1944315060668127
# Number of truck passes:  5
# Number of truck passes:  0
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  7
# Number of truck passes:  3
# Duration of rainfall [days]:  0.44927013752563527
# Intensity of rainfall [mm/hr]:  8.205826689477108
# Number of truck passes:  5
# Number of truck passes:  0
# Number of truck passes:  3
# Number of truck passes:  5
# Duration of rainfall [days]:  0.14124351221687462
# Intensity of rainfall [mm/hr]:  1.036763245624377
# Number of truck passes:  5
# Number of truck passes:  5
# Duration of rainfall [days]:  0.1658770102962569
# Intensity of rainfall [mm/hr]:  2.5561787310394517
# Number of truck passes:  6
# Number of truck passes:  8
# Number of truck passes:  5
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  4
# Duration of rainfall [days]:  0.06615777925336092
# Intensity of rainfall [mm/hr]:  3.998198091120786
# Number of truck passes:  6
# Number of truck passes:  10
# Duration of rainfall [days]:  0.24097130940071143
# Intensity of rainfall [mm/hr]:  5.061707321234352
# Number of truck passes:  2
# Number of truck passes:  3
# Number of truck passes:  9
# Number of truck passes:  6
# Number of truck passes:  9
# Number of truck passes:  3
# Duration of rainfall [days]:  0.160587096850276
# Intensity of rainfall [mm/hr]:  13.534845830690305
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  3
# Number of truck passes:  3
# Number of truck passes:  8
# Number of truck passes:  5
# Number of truck passes:  9
# Number of truck passes:  3
# Duration of rainfall [days]:  0.045250498883502965
# Intensity of rainfall [mm/hr]:  8.184088901954404
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.06202695555705334
# Intensity of rainfall [mm/hr]:  4.922947431102942
# Number of truck passes:  7
# Number of truck passes:  3
# Duration of rainfall [days]:  0.100036661669974
# Intensity of rainfall [mm/hr]:  1.34305425868504
# Number of truck passes:  5
# Number of truck passes:  7
# Duration of rainfall [days]:  0.05608396862108923
# Intensity of rainfall [mm/hr]:  4.491467765270338
# Number of truck passes:  7
# Number of truck passes:  4
# Number of truck passes:  5
# Duration of rainfall [days]:  0.24465448858394626
# Intensity of rainfall [mm/hr]:  1.1296597422889518
# Number of truck passes:  3
# Duration of rainfall [days]:  0.14479438656628857
# Intensity of rainfall [mm/hr]:  12.605598549561705
# Number of truck passes:  5
# Number of truck passes:  7
# Number of truck passes:  6
# Number of truck passes:  7
# Duration of rainfall [days]:  0.011075729796429951
# Intensity of rainfall [mm/hr]:  0.2633203604890665
# Number of truck passes:  7
# Number of truck passes:  1
# Number of truck passes:  4
# Number of truck passes:  3
# Duration of rainfall [days]:  0.014584195888354768
# Intensity of rainfall [mm/hr]:  3.7343530082187746
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  4
# Number of truck passes:  2
# Number of truck passes:  3
# Number of truck passes:  5
# Duration of rainfall [days]:  0.0265233019558569
# Intensity of rainfall [mm/hr]:  20.47922892802315
# Number of truck passes:  6
# Duration of rainfall [days]:  0.1669559733530715
# Intensity of rainfall [mm/hr]:  2.3171767221496085
# Number of truck passes:  4
# Duration of rainfall [days]:  0.30490611154973024
# Intensity of rainfall [mm/hr]:  1.1640317826134146
# Number of truck passes:  8
# Number of truck passes:  5
# Number of truck passes:  8
# Number of truck passes:  5
# Duration of rainfall [days]:  0.11111890956274584
# Intensity of rainfall [mm/hr]:  4.421430793248194
# Number of truck passes:  0
# Duration of rainfall [days]:  0.015024768098745749
# Intensity of rainfall [mm/hr]:  1.43709274602153
# Number of truck passes:  2
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  5
# Duration of rainfall [days]:  0.16192056889865086
# Intensity of rainfall [mm/hr]:  5.582395906391628
# Number of truck passes:  5
# Number of truck passes:  3
# Duration of rainfall [days]:  0.18195497515257322
# Intensity of rainfall [mm/hr]:  4.187224729985556
# Number of truck passes:  5
# Number of truck passes:  8
# Number of truck passes:  3
# Number of truck passes:  1
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  3
# Number of truck passes:  9
# Number of truck passes:  6
# Number of truck passes:  5
# Duration of rainfall [days]:  0.01051212801872806
# Intensity of rainfall [mm/hr]:  6.019959142716718
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  3
# Duration of rainfall [days]:  0.2931413952280556
# Intensity of rainfall [mm/hr]:  1.1403048063250587
# Number of truck passes:  5
# Duration of rainfall [days]:  0.312085109164591
# Intensity of rainfall [mm/hr]:  0.5768662712614563
# Number of truck passes:  5
# Number of truck passes:  2
# Duration of rainfall [days]:  1.0107009465615757
# Intensity of rainfall [mm/hr]:  2.8369644633876874
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  8
# Number of truck passes:  7
# Number of truck passes:  2
# Duration of rainfall [days]:  0.03952666841600898
# Intensity of rainfall [mm/hr]:  2.562034800103414
# Number of truck passes:  1
# Number of truck passes:  2
# Duration of rainfall [days]:  0.10877448007916657
# Intensity of rainfall [mm/hr]:  2.091391638414147
# Number of truck passes:  6
# Number of truck passes:  1
# Duration of rainfall [days]:  0.20469746548690154
# Intensity of rainfall [mm/hr]:  1.3240620465698894
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  2
# Number of truck passes:  9
# Duration of rainfall [days]:  0.01641905956174156
# Intensity of rainfall [mm/hr]:  4.77232039674452
# Number of truck passes:  4
# Duration of rainfall [days]:  0.3258898179703055
# Intensity of rainfall [mm/hr]:  0.417271934230004
# Number of truck passes:  5
# Number of truck passes:  9
# Number of truck passes:  1
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  1
# Number of truck passes:  8
# Duration of rainfall [days]:  0.4257064369513004
# Intensity of rainfall [mm/hr]:  0.5116989656510238
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  6
# Duration of rainfall [days]:  0.0011880584167584375
# Intensity of rainfall [mm/hr]:  1.8274942285092193
# Number of truck passes:  5
# Number of truck passes:  3
# Number of truck passes:  5
# Number of truck passes:  9
# Duration of rainfall [days]:  0.12812458718573944
# Intensity of rainfall [mm/hr]:  1.4121462542433543
# Number of truck passes:  5
# Duration of rainfall [days]:  0.14074175523772947
# Intensity of rainfall [mm/hr]:  0.6667657092376088
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  5
# Duration of rainfall [days]:  0.10192174267521614
# Intensity of rainfall [mm/hr]:  0.2473229873110102
# Number of truck passes:  6
# Duration of rainfall [days]:  0.26901598609253907
# Intensity of rainfall [mm/hr]:  5.997001315179514
# Number of truck passes:  8
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  4
# Duration of rainfall [days]:  0.07474092590687612
# Intensity of rainfall [mm/hr]:  0.09039758514227791
# Number of truck passes:  8
# Number of truck passes:  2
# Duration of rainfall [days]:  0.01654596605261094
# Intensity of rainfall [mm/hr]:  12.079741390647033
# Number of truck passes:  7
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  6
# Number of truck passes:  8
# Duration of rainfall [days]:  0.06902808581990016
# Intensity of rainfall [mm/hr]:  4.387652721562853
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  7
# Number of truck passes:  0
# Number of truck passes:  5
# Number of truck passes:  3
# Duration of rainfall [days]:  0.17070088282093043
# Intensity of rainfall [mm/hr]:  0.6816246762744496
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  5
# Duration of rainfall [days]:  0.18478138963894847
# Intensity of rainfall [mm/hr]:  2.0957365993527204
# Number of truck passes:  5
# Number of truck passes:  1
# Number of truck passes:  2
# Duration of rainfall [days]:  0.09916335274652704
# Intensity of rainfall [mm/hr]:  0.9055686325713925
# Number of truck passes:  3
# Duration of rainfall [days]:  0.4724712833661056
# Intensity of rainfall [mm/hr]:  2.1439879290710566
# Number of truck passes:  8
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  1
# Number of truck passes:  7
# Number of truck passes:  6
# Duration of rainfall [days]:  0.49644878244361745
# Intensity of rainfall [mm/hr]:  6.5941947781332155
# Number of truck passes:  6
# Number of truck passes:  10
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.05617638367533054
# Intensity of rainfall [mm/hr]:  13.149425634677039
# Number of truck passes:  4
# Number of truck passes:  3
# Duration of rainfall [days]:  0.4120220859672139
# Intensity of rainfall [mm/hr]:  2.7328484443731416
# Number of truck passes:  11
# Duration of rainfall [days]:  0.054605129809217154
# Intensity of rainfall [mm/hr]:  3.2707745515473703
# Number of truck passes:  7
# Number of truck passes:  8
# Duration of rainfall [days]:  0.18058545004036045
# Intensity of rainfall [mm/hr]:  3.6141998648350038
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  3
# Number of truck passes:  3
# Duration of rainfall [days]:  0.1239413560042041
# Intensity of rainfall [mm/hr]:  1.851136899968836
# Number of truck passes:  2
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.009496412013758572
# Intensity of rainfall [mm/hr]:  1.9599302365775004
# Number of truck passes:  2
# Number of truck passes:  5
# Number of truck passes:  5
# Duration of rainfall [days]:  0.5218253840191509
# Intensity of rainfall [mm/hr]:  4.389559194985061
# Number of truck passes:  3
# Number of truck passes:  7
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  1
# Duration of rainfall [days]:  0.2023859652760234
# Intensity of rainfall [mm/hr]:  7.564255871207668
# Number of truck passes:  3
# Number of truck passes:  6
# Duration of rainfall [days]:  0.6299004512313635
# Intensity of rainfall [mm/hr]:  8.21385992545017
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  3
# Duration of rainfall [days]:  0.4083270808623528
# Intensity of rainfall [mm/hr]:  2.6074675331607464
# Number of truck passes:  6
# Number of truck passes:  3
# Number of truck passes:  9
# Number of truck passes:  2
# Duration of rainfall [days]:  0.047799617507329806
# Intensity of rainfall [mm/hr]:  6.875989659214388
# Number of truck passes:  5
# Number of truck passes:  5
# Duration of rainfall [days]:  0.16468576175636834
# Intensity of rainfall [mm/hr]:  4.698251121664101
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  10
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  4
# Duration of rainfall [days]:  0.008681976888578127
# Intensity of rainfall [mm/hr]:  2.0733484927602457
# Number of truck passes:  8
# Number of truck passes:  1
# Duration of rainfall [days]:  0.2166417354273217
# Intensity of rainfall [mm/hr]:  0.5660427602952816
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  9
# Number of truck passes:  2
# Duration of rainfall [days]:  0.0056121271355237265
# Intensity of rainfall [mm/hr]:  3.6644312872040152
# Number of truck passes:  4
# Number of truck passes:  5
# Number of truck passes:  3
# Duration of rainfall [days]:  0.08118235640901647
# Intensity of rainfall [mm/hr]:  0.45960817802622667
# Number of truck passes:  4
# Number of truck passes:  2
# Duration of rainfall [days]:  0.007846904628105743
# Intensity of rainfall [mm/hr]:  0.6913173153363474
# Number of truck passes:  7
# Duration of rainfall [days]:  0.02021857742845546
# Intensity of rainfall [mm/hr]:  0.4246420658466552
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  5
# Duration of rainfall [days]:  0.3311575405295488
# Intensity of rainfall [mm/hr]:  0.9276771321188965
# Number of truck passes:  7
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  5
# Number of truck passes:  6
# Duration of rainfall [days]:  0.48655629789934385
# Intensity of rainfall [mm/hr]:  2.706057461792055
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  1
# Number of truck passes:  5
# Duration of rainfall [days]:  0.10427885627675154
# Intensity of rainfall [mm/hr]:  1.171706459852965
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  6
# Duration of rainfall [days]:  0.08798255299494673
# Intensity of rainfall [mm/hr]:  2.503493588984588
# Number of truck passes:  5
# Number of truck passes:  6
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  8
# Number of truck passes:  6
# Duration of rainfall [days]:  0.19489973142255435
# Intensity of rainfall [mm/hr]:  4.251606390173917
# Number of truck passes:  1
# Duration of rainfall [days]:  0.16254500587893111
# Intensity of rainfall [mm/hr]:  2.2502150695314898
# Number of truck passes:  4
# Number of truck passes:  0
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  6
# Duration of rainfall [days]:  0.004770231038818195
# Intensity of rainfall [mm/hr]:  3.42428890331004
# Number of truck passes:  3
# Number of truck passes:  5
# Number of truck passes:  4
# Number of truck passes:  6
# Number of truck passes:  5
# Number of truck passes:  2
# Number of truck passes:  5
# Duration of rainfall [days]:  0.04143570456980539
# Intensity of rainfall [mm/hr]:  10.860253553365098
# Number of truck passes:  6
# Number of truck passes:  7
# Number of truck passes:  3
# Number of truck passes:  4
# Number of truck passes:  2
# Number of truck passes:  6
# Number of truck passes:  6
# Duration of rainfall [days]:  0.02201581062279532
# Intensity of rainfall [mm/hr]:  16.471493757448002
# Number of truck passes:  4
# Number of truck passes:  3
# Number of truck passes:  2
# Number of truck passes:  4
# Number of truck passes:  7
# Duration of rainfall [days]:  0.06655077439037285
# Intensity of rainfall [mm/hr]:  4.21169399369088
# Number of truck passes:  12
# Duration of rainfall [days]:  0.009084817059542243
# Intensity of rainfall [mm/hr]:  1.223386009710323
# Number of truck passes:  6
# Number of truck passes:  4
# Duration of rainfall [days]:  0.16429448597059204
# Intensity of rainfall [mm/hr]:  3.4098464327700304
# Number of truck passes:  3
# Number of truck passes:  7
# Duration of rainfall [days]:  0.16504990585122598
# Intensity of rainfall [mm/hr]:  3.129536864160332
# Number of truck passes:  6
# Number of truck passes:  6
# Duration of rainfall [days]:  0.03677570378452031
# Intensity of rainfall [mm/hr]:  6.332383816853798
# Number of truck passes:  9

# %% [markdown]
# ### 5. Examine the results

# %% [markdown]
# #### Stochastically generated rainfall

# %%
plt.bar(range(0,model_end), np.multiply(intensity_arr,np.multiply(dt_arr,24)))
plt.xlabel('Day')
plt.ylabel('Rainfall [mm]')
plt.xlim(0,model_end)
plt.show()
print('Total annual rainfall: ', sum(np.multiply(intensity_arr,np.multiply(dt_arr,24))))

plt.plot(range(0,model_end), intensity_arr)
plt.xlabel('Day')
plt.ylabel('Rainfall intensity [mm/hr]')
plt.xlim(0,model_end)
plt.show()
# Out:
# Total annual rainfall:  1868.1854770563752

# %% [markdown]
# #### Cross section

# %%
xsec_active = mg.at_node['active__elev'][2196:2232]
xsec_surf =  mg.at_node['surfacing__elev'][2196:2232] 
xsec_ball = mg.at_node['ballast__elev'][2196:2232]

plt.figure(figsize=(8,3), layout='tight')
plt.plot(X[36], xsec_pre, color='gray', linestyle='-.', label='Before')
plt.plot(X[36], xsec_active, color ='black', linestyle='-', label = 'After - Active elevation')
plt.plot(X[36], xsec_surf, color ='magenta', linestyle='-', label = 'After - Surfacing elevation')
plt.plot(X[36], xsec_ball, color ='cyan', linestyle='-', label = 'After - Ballast elevation ')
plt.xlim(0,10)
plt.xlabel('Road width (m)')
plt.ylabel('Elevation (m)')
plt.legend()
plt.show()

# %% [markdown]
# #### 3D rendition of the road surface

# %%
X = mg.node_x.reshape(mg.shape)
Y = mg.node_y.reshape(mg.shape)
Z = z.reshape(mg.shape)

fig = plt.figure(figsize = (14,7))
ax = fig.add_subplot(111, projection='3d')
ax.get_proj = lambda: np.dot(Axes3D.get_proj(ax), np.diag([1, 2, 1, 1]))
ax.plot_surface(X, Y, Z, color='gray')
ax.view_init(elev=12, azim=-105)
ax.dist = 17
ax.set_xlim(0, 10)
ax.set_ylim(0, 80)
ax.set_zlim(0, 4)
ax.set_zticks(np.arange(0, 5, 1))
ax.set_xlabel('Road width (m)', labelpad=10)
ax.set_ylabel('Road length (m)', labelpad=17)
ax.set_zlabel('Elevation (m)', labelpad=10)
ax.set_zticklabels(labels=('0','1','2','3','4'))
plt.show()

# %% [markdown]
# #### Map

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(3, 6))
imshow_grid(mg, z, plot_name='Synthetic road with ruts', var_name='Elevation', var_units='m',\
    grid_units=('m', 'm'), cmap='terrain', color_for_closed='black', vmin=0, vmax=4)
plt.xlabel('Road width (m)')
plt.ylabel('Road length (m)')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Individual layer elevation changes

# %%
plt.plot(range(0,model_end), sa_arr)
plt.xlabel('Day')
plt.ylabel('Average active layer depth [m]')
plt.xlim(0,model_end)
plt.show()

plt.plot(range(0,model_end), ss_arr)
plt.xlabel('Day')
plt.ylabel('Average surfacing layer depth [m]')
plt.xlim(0,model_end)
plt.show()

plt.plot(range(0,model_end), sb_arr)
plt.xlabel('Day')
plt.ylabel('Average ballast layer depth [m]')
plt.xlim(0,model_end)
plt.show()

# %% [markdown]
# #### Cumulative elevation change and sediment load per meter of road

# %%
plt.plot(range(0,model_end), np.multiply(dz_arr_cum,1000))
plt.plot(range(0,model_end), np.zeros(len(range(0,model_end))), '--', color='gray')
plt.xlabel('Day')
plt.ylabel('Cumulative mean elevation change [m]')
plt.xlim(0,model_end)
plt.show()

total_dz = np.abs(min(dz_arr_cum))
total_dV = total_dz*0.295*0.295*270*36
total_load = total_dV*2650
sed_load = total_load/2

print('Total sediment load: ', sed_load)
# Out:
# Total sediment load:  346.4716391010409
